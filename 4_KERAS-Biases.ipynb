# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

# %%
header = ['userId', 'movieId', 'rating', 'timestamp']
ratings = pd.read_csv('./ml-100k/u.data', sep='\t', names=header)

u_unique = ratings.userId.unique()
user2Idx = {o:i for i,o in enumerate(u_unique)}

m_unique = ratings.movieId.unique()
movie2Idx = {o:i for i,o in enumerate(m_unique)}

ratings
# Out:
#        userId  movieId  rating  timestamp
# 0         196      242       3  881250949
# 1         186      302       3  891717742
# 2          22      377       1  878887116
# 3         244       51       2  880606923
# 4         166      346       1  886397596
# 5         298      474       4  884182806
# 6         115      265       2  881171488
# 7         253      465       5  891628467
# 8         305      451       3  886324817
# 9           6       86       3  883603013
# 10         62      257       2  879372434
# 11        286     1014       5  879781125
# 12        200      222       5  876042340
# 13        210       40       3  891035994
# 14        224       29       3  888104457
# 15        303      785       3  879485318
# 16        122      387       5  879270459
# 17        194      274       2  879539794
# 18        291     1042       4  874834944
# 19        234     1184       2  892079237
# 20        119      392       4  886176814
# 21        167      486       4  892738452
# 22        299      144       4  877881320
# 23        291      118       2  874833878
# 24        308        1       4  887736532
# 25         95      546       2  879196566
# 26         38       95       5  892430094
# 27        102      768       2  883748450
# 28         63      277       4  875747401
# 29        160      234       5  876861185
# ...       ...      ...     ...        ...
# 99970     449      120       1  879959573
# 99971     661      762       2  876037121
# 99972     721      874       3  877137447
# 99973     821      151       4  874792889
# 99974     764      596       3  876243046
# 99975     537      443       3  886031752
# 99976     618      628       2  891308019
# 99977     487      291       3  883445079
# 99978     113      975       5  875936424
# 99979     943      391       2  888640291
# 99980     864      685       4  888891900
# 99981     750      323       3  879445877
# 99982     279       64       1  875308510
# 99983     646      750       3  888528902
# 99984     654      370       2  887863914
# 99985     617      582       4  883789294
# 99986     913      690       3  880824288
# 99987     660      229       2  891406212
# 99988     421      498       4  892241344
# 99989     495     1091       4  888637503
# 99990     806      421       4  882388897
# 99991     676      538       4  892685437
# 99992     721      262       3  877137285
# 99993     913      209       2  881367150
# 99994     378       78       3  880056976
# 99995     880      476       3  880175444
# 99996     716      204       5  879795543
# 99997     276     1090       1  874795795
# 99998      13      225       2  882399156
# 99999      12      203       3  879959583
#
# [100000 rows x 4 columns]

# %%
ratings.userId = ratings.userId.apply(lambda x: user2Idx[x])
ratings.movieId = ratings.movieId.apply(lambda x: movie2Idx[x])

# %%
ratings
# Out:
#        userId  movieId  rating  timestamp
# 0           0        0       3  881250949
# 1           1        1       3  891717742
# 2           2        2       1  878887116
# 3           3        3       2  880606923
# 4           4        4       1  886397596
# 5           5        5       4  884182806
# 6           6        6       2  881171488
# 7           7        7       5  891628467
# 8           8        8       3  886324817
# 9           9        9       3  883603013
# 10         10       10       2  879372434
# 11         11       11       5  879781125
# 12         12       12       5  876042340
# 13         13       13       3  891035994
# 14         14       14       3  888104457
# 15         15       15       3  879485318
# 16         16       16       5  879270459
# 17         17       17       2  879539794
# 18         18       18       4  874834944
# 19         19       19       2  892079237
# 20         20       20       4  886176814
# 21         21       21       4  892738452
# 22         22       22       4  877881320
# 23         18       23       2  874833878
# 24         23       24       4  887736532
# 25         24       25       2  879196566
# 26         25       26       5  892430094
# 27         26       27       2  883748450
# 28         27       28       4  875747401
# 29         28       29       5  876861185
# ...       ...      ...     ...        ...
# 99970     441      467       1  879959573
# 99971     662      365       2  876037121
# 99972     713      736       3  877137447
# 99973     810      103       4  874792889
# 99974     759      340       3  876243046
# 99975     534      154       3  886031752
# 99976     608      862       2  891308019
# 99977     479      298       3  883445079
# 99978     146      809       5  875936424
# 99979     937      978       2  888640291
# 99980     862       97       4  888891900
# 99981     746      144       3  879445877
# 99982      75      239       1  875308510
# 99983     656      115       3  888528902
# 99984     648      381       2  887863914
# 99985     607      669       4  883789294
# 99986     915       72       3  880824288
# 99987     654       76       2  891406212
# 99988     427       91       4  892241344
# 99989     489      194       4  888637503
# 99990     803      518       4  882388897
# 99991     670     1167       4  892685437
# 99992     713      863       3  877137285
# 99993     915       93       2  881367150
# 99994     369      313       3  880056976
# 99995     875      173       3  880175444
# 99996     708      247       5  879795543
# 99997      37     1004       1  874795795
# 99998      58      443       2  882399156
# 99999     304      506       3  879959583
#
# [100000 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
ratings_train, ratings_val = train_test_split(ratings, test_size=0.2)

# %%
len(ratings_train), len(ratings_val)
# Out:
# (80000, 20000)

# %%
n_users = int(ratings.userId.nunique())
n_movies = int(ratings.movieId.nunique())
n_users_train = int(ratings_train.userId.nunique())
n_movies_train = int(ratings_train.movieId.nunique())
print(n_users, n_movies, n_users_train, n_movies_train)
# Out:
# 943 1682 943 1649

# %%
from keras.layers import Embedding, Input, Flatten, Dot, Add
from keras import Model
from keras.constraints import non_neg

# %%
n_latent_factors = 3

# %%
movie_input = Input(shape=[1], name='Item')
movie_embedding = Embedding(n_movies + 1, n_latent_factors, name='Movie-Embedding')(movie_input)
movie_vec = Flatten(name='FlattenMovies')(movie_embedding)
m_biases = Flatten()(Embedding(n_movies + 1, 1, name="movie_biases")(movie_input))

user_input = Input(shape=[1],name='User')
user_vec = Flatten(name='FlattenUsers')(Embedding(n_users + 1, n_latent_factors,name='User-Embedding')(user_input))
u_biases = Flatten()(Embedding(n_users + 1, 1, name="user_biases")(user_input))

# %%
prod = Dot(axes=1, name='DotProduct')([movie_vec, user_vec])
out = Add()([prod, u_biases, m_biases])
model = Model([user_input, movie_input], out)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Item (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# User (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# Movie-Embedding (Embedding)     (None, 1, 3)         5049        Item[0][0]
# __________________________________________________________________________________________________
# User-Embedding (Embedding)      (None, 1, 3)         2832        User[0][0]
# __________________________________________________________________________________________________
# FlattenMovies (Flatten)         (None, 3)            0           Movie-Embedding[0][0]
# __________________________________________________________________________________________________
# FlattenUsers (Flatten)          (None, 3)            0           User-Embedding[0][0]
# __________________________________________________________________________________________________
# user_biases (Embedding)         (None, 1, 1)         944         User[0][0]
# __________________________________________________________________________________________________
# movie_biases (Embedding)        (None, 1, 1)         1683        Item[0][0]
# __________________________________________________________________________________________________
# DotProduct (Dot)                (None, 1)            0           FlattenMovies[0][0]
#                                                                  FlattenUsers[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1)            0           user_biases[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1)            0           movie_biases[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 1)            0           DotProduct[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_1[0][0]
# ==================================================================================================
# Total params: 10,508
# Trainable params: 10,508
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam

# %%
from fnn_helper import PlotLosses
plot_losses = PlotLosses(1, None)

# %%
import keras.backend as K 
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

# %%
model.compile(Adam(lr=0.001), 'mean_squared_error', metrics=[root_mean_squared_error])

# %%
history = model.fit([ratings_train.userId, ratings_train.movieId], 
                    ratings_train.rating, 
                    batch_size=320,
                    validation_data=([ratings_val.userId, ratings_val.movieId], ratings_val.rating), 
                    epochs=100, 
                    callbacks = [plot_losses],
                    verbose=1)

# %%
model.evaluate([ratings_val.userId, ratings_val.movieId], ratings_val.rating)
# Out:
# 20000/20000 [==============================] - 0s 14us/step
# [0.8520862114429474, 0.7257588473796844]
